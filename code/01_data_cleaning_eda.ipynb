# %% [markdown]
# # Data Cleaning and EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Import Data

# %% [markdown]
# Initial dataset from "OtoMatch: Content-based eardrum image retrieval using deep learning" placed into three categoires:
#
# Effusion: 179 images
# Normal: 179 images
# Tubes: 96 images
#
# Images categories divided with 2/3 in each category going to train images and 1/3 of each category going to test images. Categories outline below:
#
# #### effusion
# train: 119
#
# test: 60
# #### normal
# train: 119
#
# test: 60
# #### tube
# train: 66
#
# test: 30
#
#
# From each train category 20% was used for validation split

# %%
train_gen = ImageDataGenerator(rescale = 1/255., validation_split=0.2)

train_data = train_gen.flow_from_directory('/Users/annafunsten/Desktop/dsir-322/capstone/Ear-Infection-Identifier/data/middle_ear_images/train/', subset = 'training' )

validation_data = train_gen.flow_from_directory('/Users/annafunsten/Desktop/dsir-322/capstone/Ear-Infection-Identifier/data/middle_ear_images/train/', batch_size = 32, subset = 'validation' )
# Out:
# Found 249 images belonging to 3 classes.
# Found 61 images belonging to 3 classes.

# %%
test_gen = ImageDataGenerator(rescale = 1/255.)

test_data = test_gen.flow_from_directory('/Users/annafunsten/Desktop/dsir-322/capstone/Ear-Infection-Identifier/data/middle_ear_images/test/', batch_size = 32, shuffle = False)
# Out:
# Found 162 images belonging to 3 classes.

# %% [markdown]
# ## EDA

# %% [markdown]
# #### Non Infected Fluid Behind Eardrum

# %%
test_ear_effusion = plt.imread('/Users/annafunsten/Desktop/dsir-322/capstone/Ear-Infection-Identifier/data/middle_ear_images/test/01_effusion_test/AM156L.jpg')

# %%
plt.imshow(test_ear_effusion);

# %% [markdown]
# #### Infected Fluid Behind Ear Drum

# %%
test_ear_aom = plt.imread('/Users/annafunsten/Desktop/dsir-322/capstone/Ear-Infection-Identifier/data/middle_ear_images/test/01_effusion_test/OT133523.jpg')

# %%
plt.imshow(test_ear_aom);

# %% [markdown]
# #### Ear with tympanostomy tubes(TM tubes)

# %%
test_ear_tube = plt.imread('/Users/annafunsten/Desktop/dsir-322/capstone/Ear-Infection-Identifier/data/middle_ear_images/test/02_tube_test/AM168L.jpg')

# %%
plt.imshow(test_ear_tube);

# %% [markdown]
# #### Healthy Eardrum (Normal)

# %%
test_ear_normal = plt.imread('/Users/annafunsten/Desktop/dsir-322/capstone/Ear-Infection-Identifier/data/middle_ear_images/test/03_normal_test/AM73R.jpg')

# %%
plt.imshow(test_ear_normal);

# %% [markdown]
# #### Augmented Image

# %%
test_ear_aug = plt.imread('/Users/annafunsten/Desktop/dsir-322/capstone/Ear-Infection-Identifier/data/middle_ear_images/test/01_effusion_test/NT4L.jpg')

# %%
plt.imshow(test_ear_aug);

# %% [markdown]
# blurred but visible otitis media

# %%
test_ear_aug2 = plt.imread('/Users/annafunsten/Desktop/dsir-322/capstone/Ear-Infection-Identifier/data/middle_ear_images/test/01_effusion_test/AM391l.jpg')

# %%
plt.imshow(test_ear_aug2);

# %% [markdown]
# Hard to see any landmarks in this image
