# %% [markdown]
# # Data Cleaning and EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Import Data

# %% [markdown]
# Initial dataset from "OtoMatch: Content-based eardrum image retrieval using deep learning" resorted into five categoires:
#
# Effusion: 38 images
# Normal: 173 images
# Tubes: 96 images
# Otitis Media: 80 images
# Unclear: 67 images
#
# Images categories divided into each category with .3 of each category going to test images. Categories outline below:
#
# #### effusion
# train: 30
#
# test: 8
# #### normal
# train: 139
#
# test:34
# #### tube
# train: 77
#
# test: 19
#
# #### unclear
# train: 54
#
# test: 13
#
# #### otitis media
# train 64
#
# test 16
#
# From each train category 20% was used for validation split

# %% [markdown]
# ### Import Data

# %%
train_gen = ImageDataGenerator(rescale = 1/255., validation_split=0.2)

train_data = train_gen.flow_from_directory('/Users/annafunsten/Desktop/dsir-322/capstone/Ear-Infection-Identifier/data/middle_ear_images_2/train/', subset = 'training' )

validation_data = train_gen.flow_from_directory('/Users/annafunsten/Desktop/dsir-322/capstone/Ear-Infection-Identifier/data/middle_ear_images_2/train/', batch_size = 32, subset = 'validation' )
# Out:
# Found 295 images belonging to 5 classes.
# Found 70 images belonging to 5 classes.

# %%
test_gen = ImageDataGenerator(rescale = 1/255.)

test_data = test_gen.flow_from_directory('/Users/annafunsten/Desktop/dsir-322/capstone/Ear-Infection-Identifier/data/middle_ear_images_2/test/', batch_size = 32, shuffle = False)
# Out:
# Found 90 images belonging to 5 classes.

# %% [markdown]
# ## EDA

# %% [markdown]
# #### Non Infected Fluid Behind Eardrum

# %%
test_ear_effusion = plt.imread('/Users/annafunsten/Desktop/dsir-322/capstone/Ear-Infection-Identifier/data/middle_ear_images_2/test/01_effusion/AN341R.jpg')

# %%
plt.imshow(test_ear_effusion);

# %% [markdown]
# #### Infected Fluid Behind Ear Drum

# %%
test_ear_aom = plt.imread('/Users/annafunsten/Desktop/dsir-322/capstone/Ear-Infection-Identifier/data/middle_ear_images_2/test/03_otitis_media/OT080642.jpg')

# %%
plt.imshow(test_ear_aom);

# %% [markdown]
# #### Ear with tympanostomy tubes(TM tubes)

# %%
test_ear_tube = plt.imread('/Users/annafunsten/Desktop/dsir-322/capstone/Ear-Infection-Identifier/data/middle_ear_images_2/test/04_tube/AM168L.jpg')

# %%
plt.imshow(test_ear_tube);

# %% [markdown]
# #### Healthy Eardrum (Normal)

# %%
test_ear_normal = plt.imread('/Users/annafunsten/Desktop/dsir-322/capstone/Ear-Infection-Identifier/data/middle_ear_images_2/test/02_normal/AM1L.jpg')

# %%
plt.imshow(test_ear_normal);

# %% [markdown]
# #### Unclear Image

# %%
test_ear_aug = plt.imread('/Users/annafunsten/Desktop/dsir-322/capstone/Ear-Infection-Identifier/data/middle_ear_images_2/test/05_unclear/AM355L.jpg')

# %%
plt.imshow(test_ear_aug);

# %% [markdown]
# blurred but visible otitis media
